# %%
import numpy as np
import tensorflow as tf
import time

# %%
def generate_data(data,k=4):
    T={}
    for i in range(len(data)-k):
        X=data[i:i+k]
        Y=data[i+k]
        print("X is %s and Y is %s"%(X,Y))
   # print(len(data))
        if T.get(X) is None:
            T[X]={}
            T[X][Y]=1
        else:
            if T[X].get(Y) is None:
                T[X][Y]=1
            else:
                T[X][Y]+=1
    return T

# %%
text_path="jq.txt"
def load_text(filename):
    with open(filename,encoding='utf8') as f:
        return f.read()
text=load_text(text_path)
print(text)
# Out:
# My dear countrymen,On this solemn day of Independence, many greetings to all countrymen.Today is also the festival of Raksha Bandhan. This centuries-old tradition expresses the love of brother and sister. I extend my best wishes to all the countrymen and all the brothers and sisters on this auspicious festival of Raksha Bandhan. May this festival filled with affection fulfil the hopes, aspirations and dreams of all our brothers and sisters, and bring affection in their lives.Today, while the country is celebrating the festival of independence, people in several parts of the country are facing difficulties due to floods and heavy rainfall. Many have lost their dear ones. I express my condolences to them. The State Governments, the Central Government and other organizations like NDRF are striving day and night to ease the hardships and bring the situation under control.

# %%
generate_data(text)
# Out:
# X is My d and Y is e
# X is y de and Y is a
# X is  dea and Y is r
# X is dear and Y is
# X is ear  and Y is c
# X is ar c and Y is o
# X is r co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is ,
# X is men, and Y is O
# X is en,O and Y is n
# X is n,On and Y is
# X is ,On  and Y is t
# X is On t and Y is h
# X is n th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is s
# X is is s and Y is o
# X is s so and Y is l
# X is  sol and Y is e
# X is sole and Y is m
# X is olem and Y is n
# X is lemn and Y is
# X is emn  and Y is d
# X is mn d and Y is a
# X is n da and Y is y
# X is  day and Y is
# X is day  and Y is o
# X is ay o and Y is f
# X is y of and Y is
# X is  of  and Y is I
# X is of I and Y is n
# X is f In and Y is d
# X is  Ind and Y is e
# X is Inde and Y is p
# X is ndep and Y is e
# X is depe and Y is n
# X is epen and Y is d
# X is pend and Y is e
# X is ende and Y is n
# X is nden and Y is c
# X is denc and Y is e
# X is ence and Y is ,
# X is nce, and Y is
# X is ce,  and Y is m
# X is e, m and Y is a
# X is , ma and Y is n
# X is  man and Y is y
# X is many and Y is
# X is any  and Y is g
# X is ny g and Y is r
# X is y gr and Y is e
# X is  gre and Y is e
# X is gree and Y is t
# X is reet and Y is i
# X is eeti and Y is n
# X is etin and Y is g
# X is ting and Y is s
# X is ings and Y is
# X is ngs  and Y is t
# X is gs t and Y is o
# X is s to and Y is
# X is  to  and Y is a
# X is to a and Y is l
# X is o al and Y is l
# X is  all and Y is
# X is all  and Y is c
# X is ll c and Y is o
# X is l co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is .
# X is men. and Y is T
# X is en.T and Y is o
# X is n.To and Y is d
# X is .Tod and Y is a
# X is Toda and Y is y
# X is oday and Y is
# X is day  and Y is i
# X is ay i and Y is s
# X is y is and Y is
# X is  is  and Y is a
# X is is a and Y is l
# X is s al and Y is s
# X is  als and Y is o
# X is also and Y is
# X is lso  and Y is t
# X is so t and Y is h
# X is o th and Y is e
# X is  the and Y is
# X is the  and Y is f
# X is he f and Y is e
# X is e fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is R
# X is of R and Y is a
# X is f Ra and Y is k
# X is  Rak and Y is s
# X is Raks and Y is h
# X is aksh and Y is a
# X is ksha and Y is
# X is sha  and Y is B
# X is ha B and Y is a
# X is a Ba and Y is n
# X is  Ban and Y is d
# X is Band and Y is h
# X is andh and Y is a
# X is ndha and Y is n
# X is dhan and Y is .
# X is han. and Y is
# X is an.  and Y is T
# X is n. T and Y is h
# X is . Th and Y is i
# X is  Thi and Y is s
# X is This and Y is
# X is his  and Y is c
# X is is c and Y is e
# X is s ce and Y is n
# X is  cen and Y is t
# X is cent and Y is u
# X is entu and Y is r
# X is ntur and Y is i
# X is turi and Y is e
# X is urie and Y is s
# X is ries and Y is -
# X is ies- and Y is o
# X is es-o and Y is l
# X is s-ol and Y is d
# X is -old and Y is
# X is old  and Y is t
# X is ld t and Y is r
# X is d tr and Y is a
# X is  tra and Y is d
# X is trad and Y is i
# X is radi and Y is t
# X is adit and Y is i
# X is diti and Y is o
# X is itio and Y is n
# X is tion and Y is
# X is ion  and Y is e
# X is on e and Y is x
# X is n ex and Y is p
# X is  exp and Y is r
# X is expr and Y is e
# X is xpre and Y is s
# X is pres and Y is s
# X is ress and Y is e
# X is esse and Y is s
# X is sses and Y is
# X is ses  and Y is t
# X is es t and Y is h
# X is s th and Y is e
# X is  the and Y is
# X is the  and Y is l
# X is he l and Y is o
# X is e lo and Y is v
# X is  lov and Y is e
# X is love and Y is
# X is ove  and Y is o
# X is ve o and Y is f
# X is e of and Y is
# X is  of  and Y is b
# X is of b and Y is r
# X is f br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is
# X is her  and Y is a
# X is er a and Y is n
# X is r an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is .
# X is ter. and Y is
# X is er.  and Y is I
# X is r. I and Y is
# X is . I  and Y is e
# X is  I e and Y is x
# X is I ex and Y is t
# X is  ext and Y is e
# X is exte and Y is n
# X is xten and Y is d
# X is tend and Y is
# X is end  and Y is m
# X is nd m and Y is y
# X is d my and Y is
# X is  my  and Y is b
# X is my b and Y is e
# X is y be and Y is s
# X is  bes and Y is t
# X is best and Y is
# X is est  and Y is w
# X is st w and Y is i
# X is t wi and Y is s
# X is  wis and Y is h
# X is wish and Y is e
# X is ishe and Y is s
# X is shes and Y is
# X is hes  and Y is t
# X is es t and Y is o
# X is s to and Y is
# X is  to  and Y is a
# X is to a and Y is l
# X is o al and Y is l
# X is  all and Y is
# X is all  and Y is t
# X is ll t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is
# X is men  and Y is a
# X is en a and Y is n
# X is n an and Y is d
# X is  and and Y is
# X is and  and Y is a
# X is nd a and Y is l
# X is d al and Y is l
# X is  all and Y is
# X is all  and Y is t
# X is ll t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is b
# X is he b and Y is r
# X is e br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is s
# X is hers and Y is
# X is ers  and Y is a
# X is rs a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is s
# X is ters and Y is
# X is ers  and Y is o
# X is rs o and Y is n
# X is s on and Y is
# X is  on  and Y is t
# X is on t and Y is h
# X is n th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is a
# X is is a and Y is u
# X is s au and Y is s
# X is  aus and Y is p
# X is ausp and Y is i
# X is uspi and Y is c
# X is spic and Y is i
# X is pici and Y is o
# X is icio and Y is u
# X is ciou and Y is s
# X is ious and Y is
# X is ous  and Y is f
# X is us f and Y is e
# X is s fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is R
# X is of R and Y is a
# X is f Ra and Y is k
# X is  Rak and Y is s
# X is Raks and Y is h
# X is aksh and Y is a
# X is ksha and Y is
# X is sha  and Y is B
# X is ha B and Y is a
# X is a Ba and Y is n
# X is  Ban and Y is d
# X is Band and Y is h
# X is andh and Y is a
# X is ndha and Y is n
# X is dhan and Y is .
# X is han. and Y is
# X is an.  and Y is M
# X is n. M and Y is a
# X is . Ma and Y is y
# X is  May and Y is
# X is May  and Y is t
# X is ay t and Y is h
# X is y th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is f
# X is is f and Y is e
# X is s fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is f
# X is al f and Y is i
# X is l fi and Y is l
# X is  fil and Y is l
# X is fill and Y is e
# X is ille and Y is d
# X is lled and Y is
# X is led  and Y is w
# X is ed w and Y is i
# X is d wi and Y is t
# X is  wit and Y is h
# X is with and Y is
# X is ith  and Y is a
# X is th a and Y is f
# X is h af and Y is f
# X is  aff and Y is e
# X is affe and Y is c
# X is ffec and Y is t
# X is fect and Y is i
# X is ecti and Y is o
# X is ctio and Y is n
# X is tion and Y is
# X is ion  and Y is f
# X is on f and Y is u
# X is n fu and Y is l
# X is  ful and Y is f
# X is fulf and Y is i
# X is ulfi and Y is l
# X is lfil and Y is
# X is fil  and Y is t
# X is il t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is h
# X is he h and Y is o
# X is e ho and Y is p
# X is  hop and Y is e
# X is hope and Y is s
# X is opes and Y is ,
# X is pes, and Y is
# X is es,  and Y is a
# X is s, a and Y is s
# X is , as and Y is p
# X is  asp and Y is i
# X is aspi and Y is r
# X is spir and Y is a
# X is pira and Y is t
# X is irat and Y is i
# X is rati and Y is o
# X is atio and Y is n
# X is tion and Y is s
# X is ions and Y is
# X is ons  and Y is a
# X is ns a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is d
# X is nd d and Y is r
# X is d dr and Y is e
# X is  dre and Y is a
# X is drea and Y is m
# X is ream and Y is s
# X is eams and Y is
# X is ams  and Y is o
# X is ms o and Y is f
# X is s of and Y is
# X is  of  and Y is a
# X is of a and Y is l
# X is f al and Y is l
# X is  all and Y is
# X is all  and Y is o
# X is ll o and Y is u
# X is l ou and Y is r
# X is  our and Y is
# X is our  and Y is b
# X is ur b and Y is r
# X is r br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is s
# X is hers and Y is
# X is ers  and Y is a
# X is rs a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is s
# X is ters and Y is ,
# X is ers, and Y is
# X is rs,  and Y is a
# X is s, a and Y is n
# X is , an and Y is d
# X is  and and Y is
# X is and  and Y is b
# X is nd b and Y is r
# X is d br and Y is i
# X is  bri and Y is n
# X is brin and Y is g
# X is ring and Y is
# X is ing  and Y is a
# X is ng a and Y is f
# X is g af and Y is f
# X is  aff and Y is e
# X is affe and Y is c
# X is ffec and Y is t
# X is fect and Y is i
# X is ecti and Y is o
# X is ctio and Y is n
# X is tion and Y is
# X is ion  and Y is i
# X is on i and Y is n
# X is n in and Y is
# X is  in  and Y is t
# X is in t and Y is h
# X is n th and Y is e
# X is  the and Y is i
# X is thei and Y is r
# X is heir and Y is
# X is eir  and Y is l
# X is ir l and Y is i
# X is r li and Y is v
# X is  liv and Y is e
# X is live and Y is s
# X is ives and Y is .
# X is ves. and Y is T
# X is es.T and Y is o
# X is s.To and Y is d
# X is .Tod and Y is a
# X is Toda and Y is y
# X is oday and Y is ,
# X is day, and Y is
# X is ay,  and Y is w
# X is y, w and Y is h
# X is , wh and Y is i
# X is  whi and Y is l
# X is whil and Y is e
# X is hile and Y is
# X is ile  and Y is t
# X is le t and Y is h
# X is e th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is
# X is try  and Y is i
# X is ry i and Y is s
# X is y is and Y is
# X is  is  and Y is c
# X is is c and Y is e
# X is s ce and Y is l
# X is  cel and Y is e
# X is cele and Y is b
# X is eleb and Y is r
# X is lebr and Y is a
# X is ebra and Y is t
# X is brat and Y is i
# X is rati and Y is n
# X is atin and Y is g
# X is ting and Y is
# X is ing  and Y is t
# X is ng t and Y is h
# X is g th and Y is e
# X is  the and Y is
# X is the  and Y is f
# X is he f and Y is e
# X is e fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is i
# X is of i and Y is n
# X is f in and Y is d
# X is  ind and Y is e
# X is inde and Y is p
# X is ndep and Y is e
# X is depe and Y is n
# X is epen and Y is d
# X is pend and Y is e
# X is ende and Y is n
# X is nden and Y is c
# X is denc and Y is e
# X is ence and Y is ,
# X is nce, and Y is
# X is ce,  and Y is p
# X is e, p and Y is e
# X is , pe and Y is o
# X is  peo and Y is p
# X is peop and Y is l
# X is eopl and Y is e
# X is ople and Y is
# X is ple  and Y is i
# X is le i and Y is n
# X is e in and Y is
# X is  in  and Y is s
# X is in s and Y is e
# X is n se and Y is v
# X is  sev and Y is e
# X is seve and Y is r
# X is ever and Y is a
# X is vera and Y is l
# X is eral and Y is
# X is ral  and Y is p
# X is al p and Y is a
# X is l pa and Y is r
# X is  par and Y is t
# X is part and Y is s
# X is arts and Y is
# X is rts  and Y is o
# X is ts o and Y is f
# X is s of and Y is
# X is  of  and Y is t
# X is of t and Y is h
# X is f th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is
# X is try  and Y is a
# X is ry a and Y is r
# X is y ar and Y is e
# X is  are and Y is
# X is are  and Y is f
# X is re f and Y is a
# X is e fa and Y is c
# X is  fac and Y is i
# X is faci and Y is n
# X is acin and Y is g
# X is cing and Y is
# X is ing  and Y is d
# X is ng d and Y is i
# X is g di and Y is f
# X is  dif and Y is f
# X is diff and Y is i
# X is iffi and Y is c
# X is ffic and Y is u
# X is ficu and Y is l
# X is icul and Y is t
# X is cult and Y is i
# X is ulti and Y is e
# X is ltie and Y is s
# X is ties and Y is
# X is ies  and Y is d
# X is es d and Y is u
# X is s du and Y is e
# X is  due and Y is
# X is due  and Y is t
# X is ue t and Y is o
# X is e to and Y is
# X is  to  and Y is f
# X is to f and Y is l
# X is o fl and Y is o
# X is  flo and Y is o
# X is floo and Y is d
# X is lood and Y is s
# X is oods and Y is
# X is ods  and Y is a
# X is ds a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is h
# X is nd h and Y is e
# X is d he and Y is a
# X is  hea and Y is v
# X is heav and Y is y
# X is eavy and Y is
# X is avy  and Y is r
# X is vy r and Y is a
# X is y ra and Y is i
# X is  rai and Y is n
# X is rain and Y is f
# X is ainf and Y is a
# X is infa and Y is l
# X is nfal and Y is l
# X is fall and Y is .
# X is all. and Y is
# X is ll.  and Y is M
# X is l. M and Y is a
# X is . Ma and Y is n
# X is  Man and Y is y
# X is Many and Y is
# X is any  and Y is h
# X is ny h and Y is a
# X is y ha and Y is v
# X is  hav and Y is e
# X is have and Y is
# X is ave  and Y is l
# X is ve l and Y is o
# X is e lo and Y is s
# X is  los and Y is t
# X is lost and Y is
# X is ost  and Y is t
# X is st t and Y is h
# X is t th and Y is e
# X is  the and Y is i
# X is thei and Y is r
# X is heir and Y is
# X is eir  and Y is d
# X is ir d and Y is e
# X is r de and Y is a
# X is  dea and Y is r
# X is dear and Y is
# X is ear  and Y is o
# X is ar o and Y is n
# X is r on and Y is e
# X is  one and Y is s
# X is ones and Y is .
# X is nes. and Y is
# X is es.  and Y is I
# X is s. I and Y is
# X is . I  and Y is e
# X is  I e and Y is x
# X is I ex and Y is p
# X is  exp and Y is r
# X is expr and Y is e
# X is xpre and Y is s
# X is pres and Y is s
# X is ress and Y is
# X is ess  and Y is m
# X is ss m and Y is y
# X is s my and Y is
# X is  my  and Y is c
# X is my c and Y is o
# X is y co and Y is n
# X is  con and Y is d
# X is cond and Y is o
# X is ondo and Y is l
# X is ndol and Y is e
# X is dole and Y is n
# X is olen and Y is c
# X is lenc and Y is e
# X is ence and Y is s
# X is nces and Y is
# X is ces  and Y is t
# X is es t and Y is o
# X is s to and Y is
# X is  to  and Y is t
# X is to t and Y is h
# X is o th and Y is e
# X is  the and Y is m
# X is them and Y is .
# X is hem. and Y is
# X is em.  and Y is T
# X is m. T and Y is h
# X is . Th and Y is e
# X is  The and Y is
# X is The  and Y is S
# X is he S and Y is t
# X is e St and Y is a
# X is  Sta and Y is t
# X is Stat and Y is e
# X is tate and Y is
# X is ate  and Y is G
# X is te G and Y is o
# X is e Go and Y is v
# X is  Gov and Y is e
# X is Gove and Y is r
# X is over and Y is n
# X is vern and Y is m
# X is ernm and Y is e
# X is rnme and Y is n
# X is nmen and Y is t
# X is ment and Y is s
# X is ents and Y is ,
# X is nts, and Y is
# X is ts,  and Y is t
# X is s, t and Y is h
# X is , th and Y is e
# X is  the and Y is
# X is the  and Y is C
# X is he C and Y is e
# X is e Ce and Y is n
# X is  Cen and Y is t
# X is Cent and Y is r
# X is entr and Y is a
# X is ntra and Y is l
# X is tral and Y is
# X is ral  and Y is G
# X is al G and Y is o
# X is l Go and Y is v
# X is  Gov and Y is e
# X is Gove and Y is r
# X is over and Y is n
# X is vern and Y is m
# X is ernm and Y is e
# X is rnme and Y is n
# X is nmen and Y is t
# X is ment and Y is
# X is ent  and Y is a
# X is nt a and Y is n
# X is t an and Y is d
# X is  and and Y is
# X is and  and Y is o
# X is nd o and Y is t
# X is d ot and Y is h
# X is  oth and Y is e
# X is othe and Y is r
# X is ther and Y is
# X is her  and Y is o
# X is er o and Y is r
# X is r or and Y is g
# X is  org and Y is a
# X is orga and Y is n
# X is rgan and Y is i
# X is gani and Y is z
# X is aniz and Y is a
# X is niza and Y is t
# X is izat and Y is i
# X is zati and Y is o
# X is atio and Y is n
# X is tion and Y is s
# X is ions and Y is
# X is ons  and Y is l
# X is ns l and Y is i
# X is s li and Y is k
# X is  lik and Y is e
# X is like and Y is
# X is ike  and Y is N
# X is ke N and Y is D
# X is e ND and Y is R
# X is  NDR and Y is F
# X is NDRF and Y is
# X is DRF  and Y is a
# X is RF a and Y is r
# X is F ar and Y is e
# X is  are and Y is
# X is are  and Y is s
# X is re s and Y is t
# X is e st and Y is r
# X is  str and Y is i
# X is stri and Y is v
# X is triv and Y is i
# X is rivi and Y is n
# X is ivin and Y is g
# X is ving and Y is
# X is ing  and Y is d
# X is ng d and Y is a
# X is g da and Y is y
# X is  day and Y is
# X is day  and Y is a
# X is ay a and Y is n
# X is y an and Y is d
# X is  and and Y is
# X is and  and Y is n
# X is nd n and Y is i
# X is d ni and Y is g
# X is  nig and Y is h
# X is nigh and Y is t
# X is ight and Y is
# X is ght  and Y is t
# X is ht t and Y is o
# X is t to and Y is
# X is  to  and Y is e
# X is to e and Y is a
# X is o ea and Y is s
# X is  eas and Y is e
# X is ease and Y is
# X is ase  and Y is t
# X is se t and Y is h
# X is e th and Y is e
# X is  the and Y is
# X is the  and Y is h
# X is he h and Y is a
# X is e ha and Y is r
# X is  har and Y is d
# X is hard and Y is s
# X is ards and Y is h
# X is rdsh and Y is i
# X is dshi and Y is p
# X is ship and Y is s
# X is hips and Y is
# X is ips  and Y is a
# X is ps a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is b
# X is nd b and Y is r
# X is d br and Y is i
# X is  bri and Y is n
# X is brin and Y is g
# X is ring and Y is
# X is ing  and Y is t
# X is ng t and Y is h
# X is g th and Y is e
# X is  the and Y is
# X is the  and Y is s
# X is he s and Y is i
# X is e si and Y is t
# X is  sit and Y is u
# X is situ and Y is a
# X is itua and Y is t
# X is tuat and Y is i
# X is uati and Y is o
# X is atio and Y is n
# X is tion and Y is
# X is ion  and Y is u
# X is on u and Y is n
# X is n un and Y is d
# X is  und and Y is e
# X is unde and Y is r
# X is nder and Y is
# X is der  and Y is c
# X is er c and Y is o
# X is r co and Y is n
# X is  con and Y is t
# X is cont and Y is r
# X is ontr and Y is o
# X is ntro and Y is l
# X is trol and Y is .
# {'My d': {'e': 1},
#  'y de': {'a': 1},
#  ' dea': {'r': 2},
#  'dear': {' ': 2},
#  'ear ': {'c': 1, 'o': 1},
#  'ar c': {'o': 1},
#  'r co': {'u': 1, 'n': 1},
#  ' cou': {'n': 5},
#  'coun': {'t': 5},
#  'ount': {'r': 5},
#  'untr': {'y': 5},
#  'ntry': {'m': 3, ' ': 2},
#  'trym': {'e': 3},
#  'ryme': {'n': 3},
#  'ymen': {',': 1, '.': 1, ' ': 1},
#  'men,': {'O': 1},
#  'en,O': {'n': 1},
#  'n,On': {' ': 1},
#  ',On ': {'t': 1},
#  'On t': {'h': 1},
#  'n th': {'i': 2, 'e': 1},
#  ' thi': {'s': 3},
#  'this': {' ': 3},
#  'his ': {'s': 1, 'c': 1, 'a': 1, 'f': 1},
#  'is s': {'o': 1},
#  's so': {'l': 1},
#  ' sol': {'e': 1},
#  'sole': {'m': 1},
#  'olem': {'n': 1},
#  'lemn': {' ': 1},
#  'emn ': {'d': 1},
#  'mn d': {'a': 1},
#  'n da': {'y': 1},
#  ' day': {' ': 2},
#  'day ': {'o': 1, 'i': 1, 'a': 1},
#  'ay o': {'f': 1},
#  'y of': {' ': 1},
#  ' of ': {'I': 1, 'R': 2, 'b': 1, 'a': 1, 'i': 1, 't': 1},
#  'of I': {'n': 1},
#  'f In': {'d': 1},
#  ' Ind': {'e': 1},
#  'Inde': {'p': 1},
#  'ndep': {'e': 2},
#  'depe': {'n': 2},
#  'epen': {'d': 2},
#  'pend': {'e': 2},
#  'ende': {'n': 2},
#  'nden': {'c': 2},
#  'denc': {'e': 2},
#  'ence': {',': 2, 's': 1},
#  'nce,': {' ': 2},
#  'ce, ': {'m': 1, 'p': 1},
#  'e, m': {'a': 1},
#  ', ma': {'n': 1},
#  ' man': {'y': 1},
#  'many': {' ': 1},
#  'any ': {'g': 1, 'h': 1},
#  'ny g': {'r': 1},
#  'y gr': {'e': 1},
#  ' gre': {'e': 1},
#  'gree': {'t': 1},
#  'reet': {'i': 1},
#  'eeti': {'n': 1},
#  'etin': {'g': 1},
#  'ting': {'s': 1, ' ': 1},
#  'ings': {' ': 1},
#  'ngs ': {'t': 1},
#  'gs t': {'o': 1},
#  's to': {' ': 3},
#  ' to ': {'a': 2, 'f': 1, 't': 1, 'e': 1},
#  'to a': {'l': 2},
#  'o al': {'l': 2},
#  ' all': {' ': 4},
#  'all ': {'c': 1, 't': 2, 'o': 1},
#  'll c': {'o': 1},
#  'l co': {'u': 1},
#  'men.': {'T': 1},
#  'en.T': {'o': 1},
#  'n.To': {'d': 1},
#  '.Tod': {'a': 2},
#  'Toda': {'y': 2},
#  'oday': {' ': 1, ',': 1},
#  'ay i': {'s': 1},
#  'y is': {' ': 2},
#  ' is ': {'a': 1, 'c': 1},
#  'is a': {'l': 1, 'u': 1},
#  's al': {'s': 1},
#  ' als': {'o': 1},
#  'also': {' ': 1},
#  'lso ': {'t': 1},
#  'so t': {'h': 1},
#  'o th': {'e': 2},
#  ' the': {' ': 11, 'i': 2, 'm': 1},
#  'the ': {'f': 2, 'l': 1, 'c': 3, 'b': 1, 'h': 2, 'C': 1, 's': 1},
#  'he f': {'e': 2},
#  'e fe': {'s': 2},
#  ' fes': {'t': 4},
#  'fest': {'i': 4},
#  'esti': {'v': 4},
#  'stiv': {'a': 4},
#  'tiva': {'l': 4},
#  'ival': {' ': 4},
#  'val ': {'o': 3, 'f': 1},
#  'al o': {'f': 3},
#  'l of': {' ': 3},
#  'of R': {'a': 2},
#  'f Ra': {'k': 2},
#  ' Rak': {'s': 2},
#  'Raks': {'h': 2},
#  'aksh': {'a': 2},
#  'ksha': {' ': 2},
#  'sha ': {'B': 2},
#  'ha B': {'a': 2},
#  'a Ba': {'n': 2},
#  ' Ban': {'d': 2},
#  'Band': {'h': 2},
#  'andh': {'a': 2},
#  'ndha': {'n': 2},
#  'dhan': {'.': 2},
#  'han.': {' ': 2},
#  'an. ': {'T': 1, 'M': 1},
#  'n. T': {'h': 1},
#  '. Th': {'i': 1, 'e': 1},
#  ' Thi': {'s': 1},
#  'This': {' ': 1},
#  'is c': {'e': 2},
#  's ce': {'n': 1, 'l': 1},
#  ' cen': {'t': 1},
#  'cent': {'u': 1},
#  'entu': {'r': 1},
#  'ntur': {'i': 1},
#  'turi': {'e': 1},
#  'urie': {'s': 1},
#  'ries': {'-': 1},
#  'ies-': {'o': 1},
#  'es-o': {'l': 1},
#  's-ol': {'d': 1},
#  '-old': {' ': 1},
#  'old ': {'t': 1},
#  'ld t': {'r': 1},
#  'd tr': {'a': 1},
#  ' tra': {'d': 1},
#  'trad': {'i': 1},
#  'radi': {'t': 1},
#  'adit': {'i': 1},
#  'diti': {'o': 1},
#  'itio': {'n': 1},
#  'tion': {' ': 4, 's': 2},
#  'ion ': {'e': 1, 'f': 1, 'i': 1, 'u': 1},
#  'on e': {'x': 1},
#  'n ex': {'p': 1},
#  ' exp': {'r': 2},
#  'expr': {'e': 2},
#  'xpre': {'s': 2},
#  'pres': {'s': 2},
#  'ress': {'e': 1, ' ': 1},
#  'esse': {'s': 1},
#  'sses': {' ': 1},
#  'ses ': {'t': 1},
#  'es t': {'h': 1, 'o': 2},
#  's th': {'e': 1},
#  'he l': {'o': 1},
#  'e lo': {'v': 1, 's': 1},
#  ' lov': {'e': 1},
#  'love': {' ': 1},
#  'ove ': {'o': 1},
#  've o': {'f': 1},
#  'e of': {' ': 1},
#  'of b': {'r': 1},
#  'f br': {'o': 1},
#  ' bro': {'t': 3},
#  'brot': {'h': 3},
#  'roth': {'e': 3},
#  'othe': {'r': 4},
#  'ther': {' ': 2, 's': 2},
#  'her ': {'a': 1, 'o': 1},
#  'er a': {'n': 1},
#  'r an': {'d': 1},
#  ' and': {' ': 10},
#  'and ': {'s': 3, 'a': 1, 'd': 1, 'b': 2, 'h': 1, 'o': 1, 'n': 1},
#  'nd s': {'i': 3},
#  'd si': {'s': 3},
#  ' sis': {'t': 3},
#  'sist': {'e': 3},
#  'iste': {'r': 3},
#  'ster': {'.': 1, 's': 2},
#  'ter.': {' ': 1},
#  'er. ': {'I': 1},
#  'r. I': {' ': 1},
#  '. I ': {'e': 2},
#  ' I e': {'x': 2},
#  'I ex': {'t': 1, 'p': 1},
#  ' ext': {'e': 1},
#  'exte': {'n': 1},
#  'xten': {'d': 1},
#  'tend': {' ': 1},
#  'end ': {'m': 1},
#  'nd m': {'y': 1},
#  'd my': {' ': 1},
#  ' my ': {'b': 1, 'c': 1},
#  'my b': {'e': 1},
#  'y be': {'s': 1},
#  ' bes': {'t': 1},
#  'best': {' ': 1},
#  'est ': {'w': 1},
#  'st w': {'i': 1},
#  't wi': {'s': 1},
#  ' wis': {'h': 1},
#  'wish': {'e': 1},
#  'ishe': {'s': 1},
#  'shes': {' ': 1},
#  'hes ': {'t': 1},
#  'll t': {'h': 2},
#  'l th': {'e': 3},
#  'he c': {'o': 3},
#  'e co': {'u': 3},
#  'men ': {'a': 1},
#  'en a': {'n': 1},
#  'n an': {'d': 1},
#  'nd a': {'l': 1},
#  'd al': {'l': 1},
#  'he b': {'r': 1},
#  'e br': {'o': 1},
#  'hers': {' ': 2},
#  'ers ': {'a': 2, 'o': 1},
#  'rs a': {'n': 2},
#  's an': {'d': 5},
#  'ters': {' ': 1, ',': 1},
#  'rs o': {'n': 1},
#  's on': {' ': 1},
#  ' on ': {'t': 1},
#  'on t': {'h': 1},
#  's au': {'s': 1},
#  ' aus': {'p': 1},
#  'ausp': {'i': 1},
#  'uspi': {'c': 1},
#  'spic': {'i': 1},
#  'pici': {'o': 1},
#  'icio': {'u': 1},
#  'ciou': {'s': 1},
#  'ious': {' ': 1},
#  'ous ': {'f': 1},
#  'us f': {'e': 1},
#  's fe': {'s': 2},
#  'n. M': {'a': 1},
#  '. Ma': {'y': 1, 'n': 1},
#  ' May': {' ': 1},
#  'May ': {'t': 1},
#  'ay t': {'h': 1},
#  'y th': {'i': 1},
#  'is f': {'e': 1},
#  'al f': {'i': 1},
#  'l fi': {'l': 1},
#  ' fil': {'l': 1},
#  'fill': {'e': 1},
#  'ille': {'d': 1},
#  'lled': {' ': 1},
#  'led ': {'w': 1},
#  'ed w': {'i': 1},
#  'd wi': {'t': 1},
#  ' wit': {'h': 1},
#  'with': {' ': 1},
#  'ith ': {'a': 1},
#  'th a': {'f': 1},
#  'h af': {'f': 1},
#  ' aff': {'e': 2},
#  'affe': {'c': 2},
#  'ffec': {'t': 2},
#  'fect': {'i': 2},
#  'ecti': {'o': 2},
#  'ctio': {'n': 2},
#  'on f': {'u': 1},
#  'n fu': {'l': 1},
#  ' ful': {'f': 1},
#  'fulf': {'i': 1},
#  'ulfi': {'l': 1},
#  'lfil': {' ': 1},
#  'fil ': {'t': 1},
#  'il t': {'h': 1},
#  'he h': {'o': 1, 'a': 1},
#  'e ho': {'p': 1},
#  ' hop': {'e': 1},
#  'hope': {'s': 1},
#  'opes': {',': 1},
#  'pes,': {' ': 1},
#  'es, ': {'a': 1},
#  's, a': {'s': 1, 'n': 1},
#  ', as': {'p': 1},
#  ' asp': {'i': 1},
#  'aspi': {'r': 1},
#  'spir': {'a': 1},
#  'pira': {'t': 1},
#  'irat': {'i': 1},
#  'rati': {'o': 1, 'n': 1},
#  'atio': {'n': 3},
#  'ions': {' ': 2},
#  'ons ': {'a': 1, 'l': 1},
#  'ns a': {'n': 1},
#  'nd d': {'r': 1},
#  'd dr': {'e': 1},
#  ' dre': {'a': 1},
#  'drea': {'m': 1},
#  'ream': {'s': 1},
#  'eams': {' ': 1},
#  'ams ': {'o': 1},
#  'ms o': {'f': 1},
#  's of': {' ': 2},
#  'of a': {'l': 1},
#  'f al': {'l': 1},
#  'll o': {'u': 1},
#  'l ou': {'r': 1},
#  ' our': {' ': 1},
#  'our ': {'b': 1},
#  'ur b': {'r': 1},
#  'r br': {'o': 1},
#  'ers,': {' ': 1},
#  'rs, ': {'a': 1},
#  ', an': {'d': 1},
#  'nd b': {'r': 2},
#  'd br': {'i': 2},
#  ' bri': {'n': 2},
#  'brin': {'g': 2},
#  'ring': {' ': 2},
#  'ing ': {'a': 1, 't': 2, 'd': 2},
#  'ng a': {'f': 1},
#  'g af': {'f': 1},
#  'on i': {'n': 1},
#  'n in': {' ': 1},
#  ' in ': {'t': 1, 's': 1},
#  'in t': {'h': 1},
#  'thei': {'r': 2},
#  'heir': {' ': 2},
#  'eir ': {'l': 1, 'd': 1},
#  'ir l': {'i': 1},
#  'r li': {'v': 1},
#  ' liv': {'e': 1},
#  'live': {'s': 1},
#  'ives': {'.': 1},
#  'ves.': {'T': 1},
#  'es.T': {'o': 1},
#  's.To': {'d': 1},
#  'day,': {' ': 1},
#  'ay, ': {'w': 1},
#  'y, w': {'h': 1},
#  ', wh': {'i': 1},
#  ' whi': {'l': 1},
#  'whil': {'e': 1},
#  'hile': {' ': 1},
#  'ile ': {'t': 1},
#  'le t': {'h': 1},
#  'e th': {'e': 2},
#  'try ': {'i': 1, 'a': 1},
#  'ry i': {'s': 1},
#  ' cel': {'e': 1},
#  'cele': {'b': 1},
#  'eleb': {'r': 1},
#  'lebr': {'a': 1},
#  'ebra': {'t': 1},
#  'brat': {'i': 1},
#  'atin': {'g': 1},
#  'ng t': {'h': 2},
#  'g th': {'e': 2},
#  'of i': {'n': 1},
#  'f in': {'d': 1},
#  ' ind': {'e': 1},
#  'inde': {'p': 1},
#  'e, p': {'e': 1},
#  ', pe': {'o': 1},
#  ' peo': {'p': 1},
#  'peop': {'l': 1},
#  'eopl': {'e': 1},
#  'ople': {' ': 1},
#  'ple ': {'i': 1},
#  'le i': {'n': 1},
#  'e in': {' ': 1},
#  'in s': {'e': 1},
#  'n se': {'v': 1},
#  ' sev': {'e': 1},
#  'seve': {'r': 1},
#  'ever': {'a': 1},
#  'vera': {'l': 1},
#  'eral': {' ': 1},
#  'ral ': {'p': 1, 'G': 1},
#  'al p': {'a': 1},
#  'l pa': {'r': 1},
#  ' par': {'t': 1},
#  'part': {'s': 1},
#  'arts': {' ': 1},
#  'rts ': {'o': 1},
#  'ts o': {'f': 1},
#  'of t': {'h': 1},
#  'f th': {'e': 1},
#  'ry a': {'r': 1},
#  'y ar': {'e': 1},
#  ' are': {' ': 2},
#  'are ': {'f': 1, 's': 1},
#  're f': {'a': 1},
#  'e fa': {'c': 1},
#  ' fac': {'i': 1},
#  'faci': {'n': 1},
#  'acin': {'g': 1},
#  'cing': {' ': 1},
#  'ng d': {'i': 1, 'a': 1},
#  'g di': {'f': 1},
#  ' dif': {'f': 1},
#  'diff': {'i': 1},
#  'iffi': {'c': 1},
#  'ffic': {'u': 1},
#  'ficu': {'l': 1},
#  'icul': {'t': 1},
#  'cult': {'i': 1},
#  'ulti': {'e': 1},
#  'ltie': {'s': 1},
#  'ties': {' ': 1},
#  'ies ': {'d': 1},
#  'es d': {'u': 1},
#  's du': {'e': 1},
#  ' due': {' ': 1},
#  'due ': {'t': 1},
#  'ue t': {'o': 1},
#  'e to': {' ': 1},
#  'to f': {'l': 1},
#  'o fl': {'o': 1},
#  ' flo': {'o': 1},
#  'floo': {'d': 1},
#  'lood': {'s': 1},
#  'oods': {' ': 1},
#  'ods ': {'a': 1},
#  'ds a': {'n': 1},
#  'nd h': {'e': 1},
#  'd he': {'a': 1},
#  ' hea': {'v': 1},
#  'heav': {'y': 1},
#  'eavy': {' ': 1},
#  'avy ': {'r': 1},
#  'vy r': {'a': 1},
#  'y ra': {'i': 1},
#  ' rai': {'n': 1},
#  'rain': {'f': 1},
#  'ainf': {'a': 1},
#  'infa': {'l': 1},
#  'nfal': {'l': 1},
#  'fall': {'.': 1},
#  'all.': {' ': 1},
#  'll. ': {'M': 1},
#  'l. M': {'a': 1},
#  ' Man': {'y': 1},
#  'Many': {' ': 1},
#  'ny h': {'a': 1},
#  'y ha': {'v': 1},
#  ' hav': {'e': 1},
#  'have': {' ': 1},
#  'ave ': {'l': 1},
#  've l': {'o': 1},
#  ' los': {'t': 1},
#  'lost': {' ': 1},
#  'ost ': {'t': 1},
#  'st t': {'h': 1},
#  't th': {'e': 1},
#  'ir d': {'e': 1},
#  'r de': {'a': 1},
#  'ar o': {'n': 1},
#  'r on': {'e': 1},
#  ' one': {'s': 1},
#  'ones': {'.': 1},
#  'nes.': {' ': 1},
#  'es. ': {'I': 1},
#  's. I': {' ': 1},
#  'ess ': {'m': 1},
#  'ss m': {'y': 1},
#  's my': {' ': 1},
#  'my c': {'o': 1},
#  'y co': {'n': 1},
#  ' con': {'d': 1, 't': 1},
#  'cond': {'o': 1},
#  'ondo': {'l': 1},
#  'ndol': {'e': 1},
#  'dole': {'n': 1},
#  'olen': {'c': 1},
#  'lenc': {'e': 1},
#  'nces': {' ': 1},
#  'ces ': {'t': 1},
#  'to t': {'h': 1},
#  'them': {'.': 1},
#  'hem.': {' ': 1},
#  'em. ': {'T': 1},
#  'm. T': {'h': 1},
#  ' The': {' ': 1},
#  'The ': {'S': 1},
#  'he S': {'t': 1},
#  'e St': {'a': 1},
#  ' Sta': {'t': 1},
#  'Stat': {'e': 1},
#  'tate': {' ': 1},
#  'ate ': {'G': 1},
#  'te G': {'o': 1},
#  'e Go': {'v': 1},
#  ' Gov': {'e': 2},
#  'Gove': {'r': 2},
#  'over': {'n': 2},
#  'vern': {'m': 2},
#  'ernm': {'e': 2},
#  'rnme': {'n': 2},
#  'nmen': {'t': 2},
#  'ment': {'s': 1, ' ': 1},
#  'ents': {',': 1},
#  'nts,': {' ': 1},
#  'ts, ': {'t': 1},
#  's, t': {'h': 1},
#  ', th': {'e': 1},
#  'he C': {'e': 1},
#  'e Ce': {'n': 1},
#  ' Cen': {'t': 1},
#  'Cent': {'r': 1},
#  'entr': {'a': 1},
#  'ntra': {'l': 1},
#  'tral': {' ': 1},
#  'al G': {'o': 1},
#  'l Go': {'v': 1},
#  'ent ': {'a': 1},
#  'nt a': {'n': 1},
#  't an': {'d': 1},
#  'nd o': {'t': 1},
#  'd ot': {'h': 1},
#  ' oth': {'e': 1},
#  'er o': {'r': 1},
#  'r or': {'g': 1},
#  ' org': {'a': 1},
#  'orga': {'n': 1},
#  'rgan': {'i': 1},
#  'gani': {'z': 1},
#  'aniz': {'a': 1},
#  'niza': {'t': 1},
#  'izat': {'i': 1},
#  'zati': {'o': 1},
#  'ns l': {'i': 1},
#  's li': {'k': 1},
#  ' lik': {'e': 1},
#  'like': {' ': 1},
#  'ike ': {'N': 1},
#  'ke N': {'D': 1},
#  'e ND': {'R': 1},
#  ' NDR': {'F': 1},
#  'NDRF': {' ': 1},
#  'DRF ': {'a': 1},
#  'RF a': {'r': 1},
#  'F ar': {'e': 1},
#  're s': {'t': 1},
#  'e st': {'r': 1},
#  ' str': {'i': 1},
#  'stri': {'v': 1},
#  'triv': {'i': 1},
#  'rivi': {'n': 1},
#  'ivin': {'g': 1},
#  'ving': {' ': 1},
#  'g da': {'y': 1},
#  'ay a': {'n': 1},
#  'y an': {'d': 1},
#  'nd n': {'i': 1},
#  'd ni': {'g': 1},
#  ' nig': {'h': 1},
#  'nigh': {'t': 1},
#  'ight': {' ': 1},
#  'ght ': {'t': 1},
#  'ht t': {'o': 1},
#  't to': {' ': 1},
#  'to e': {'a': 1},
#  'o ea': {'s': 1},
#  ' eas': {'e': 1},
#  'ease': {' ': 1},
#  'ase ': {'t': 1},
#  'se t': {'h': 1},
#  'e ha': {'r': 1},
#  ' har': {'d': 1},
#  'hard': {'s': 1},
#  'ards': {'h': 1},
#  'rdsh': {'i': 1},
#  'dshi': {'p': 1},
#  'ship': {'s': 1},
#  'hips': {' ': 1},
#  'ips ': {'a': 1},
#  'ps a': {'n': 1},
#  'he s': {'i': 1},
#  'e si': {'t': 1},
#  ' sit': {'u': 1},
#  'situ': {'a': 1},
#  'itua': {'t': 1},
#  'tuat': {'i': 1},
#  'uati': {'o': 1},
#  'on u': {'n': 1},
#  'n un': {'d': 1},
#  ' und': {'e': 1},
#  'unde': {'r': 1},
#  'nder': {' ': 1},
#  'der ': {'c': 1},
#  'er c': {'o': 1},
#  'cont': {'r': 1},
#  'ontr': {'o': 1},
#  'ntro': {'l': 1},
#  'trol': {'.': 1}}

# %%
#Now convert these frequencies into probabilities

# %%
def convertFreqToProb(T):
    for kx in T.keys():
        s=float(sum(T[kx].values()))
        for k in T[kx].keys():
            T[kx][k]=T[kx][k]/s
    return T

# %%
def trainMarkovChain(text,k=4):
    T=generate_data(text,k)
    T=convertFreqToProb(T)
    return T
model=trainMarkovChain(text)
print(model)
# Out:
# X is My d and Y is e
# X is y de and Y is a
# X is  dea and Y is r
# X is dear and Y is
# X is ear  and Y is c
# X is ar c and Y is o
# X is r co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is ,
# X is men, and Y is O
# X is en,O and Y is n
# X is n,On and Y is
# X is ,On  and Y is t
# X is On t and Y is h
# X is n th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is s
# X is is s and Y is o
# X is s so and Y is l
# X is  sol and Y is e
# X is sole and Y is m
# X is olem and Y is n
# X is lemn and Y is
# X is emn  and Y is d
# X is mn d and Y is a
# X is n da and Y is y
# X is  day and Y is
# X is day  and Y is o
# X is ay o and Y is f
# X is y of and Y is
# X is  of  and Y is I
# X is of I and Y is n
# X is f In and Y is d
# X is  Ind and Y is e
# X is Inde and Y is p
# X is ndep and Y is e
# X is depe and Y is n
# X is epen and Y is d
# X is pend and Y is e
# X is ende and Y is n
# X is nden and Y is c
# X is denc and Y is e
# X is ence and Y is ,
# X is nce, and Y is
# X is ce,  and Y is m
# X is e, m and Y is a
# X is , ma and Y is n
# X is  man and Y is y
# X is many and Y is
# X is any  and Y is g
# X is ny g and Y is r
# X is y gr and Y is e
# X is  gre and Y is e
# X is gree and Y is t
# X is reet and Y is i
# X is eeti and Y is n
# X is etin and Y is g
# X is ting and Y is s
# X is ings and Y is
# X is ngs  and Y is t
# X is gs t and Y is o
# X is s to and Y is
# X is  to  and Y is a
# X is to a and Y is l
# X is o al and Y is l
# X is  all and Y is
# X is all  and Y is c
# X is ll c and Y is o
# X is l co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is .
# X is men. and Y is T
# X is en.T and Y is o
# X is n.To and Y is d
# X is .Tod and Y is a
# X is Toda and Y is y
# X is oday and Y is
# X is day  and Y is i
# X is ay i and Y is s
# X is y is and Y is
# X is  is  and Y is a
# X is is a and Y is l
# X is s al and Y is s
# X is  als and Y is o
# X is also and Y is
# X is lso  and Y is t
# X is so t and Y is h
# X is o th and Y is e
# X is  the and Y is
# X is the  and Y is f
# X is he f and Y is e
# X is e fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is R
# X is of R and Y is a
# X is f Ra and Y is k
# X is  Rak and Y is s
# X is Raks and Y is h
# X is aksh and Y is a
# X is ksha and Y is
# X is sha  and Y is B
# X is ha B and Y is a
# X is a Ba and Y is n
# X is  Ban and Y is d
# X is Band and Y is h
# X is andh and Y is a
# X is ndha and Y is n
# X is dhan and Y is .
# X is han. and Y is
# X is an.  and Y is T
# X is n. T and Y is h
# X is . Th and Y is i
# X is  Thi and Y is s
# X is This and Y is
# X is his  and Y is c
# X is is c and Y is e
# X is s ce and Y is n
# X is  cen and Y is t
# X is cent and Y is u
# X is entu and Y is r
# X is ntur and Y is i
# X is turi and Y is e
# X is urie and Y is s
# X is ries and Y is -
# X is ies- and Y is o
# X is es-o and Y is l
# X is s-ol and Y is d
# X is -old and Y is
# X is old  and Y is t
# X is ld t and Y is r
# X is d tr and Y is a
# X is  tra and Y is d
# X is trad and Y is i
# X is radi and Y is t
# X is adit and Y is i
# X is diti and Y is o
# X is itio and Y is n
# X is tion and Y is
# X is ion  and Y is e
# X is on e and Y is x
# X is n ex and Y is p
# X is  exp and Y is r
# X is expr and Y is e
# X is xpre and Y is s
# X is pres and Y is s
# X is ress and Y is e
# X is esse and Y is s
# X is sses and Y is
# X is ses  and Y is t
# X is es t and Y is h
# X is s th and Y is e
# X is  the and Y is
# X is the  and Y is l
# X is he l and Y is o
# X is e lo and Y is v
# X is  lov and Y is e
# X is love and Y is
# X is ove  and Y is o
# X is ve o and Y is f
# X is e of and Y is
# X is  of  and Y is b
# X is of b and Y is r
# X is f br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is
# X is her  and Y is a
# X is er a and Y is n
# X is r an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is .
# X is ter. and Y is
# X is er.  and Y is I
# X is r. I and Y is
# X is . I  and Y is e
# X is  I e and Y is x
# X is I ex and Y is t
# X is  ext and Y is e
# X is exte and Y is n
# X is xten and Y is d
# X is tend and Y is
# X is end  and Y is m
# X is nd m and Y is y
# X is d my and Y is
# X is  my  and Y is b
# X is my b and Y is e
# X is y be and Y is s
# X is  bes and Y is t
# X is best and Y is
# X is est  and Y is w
# X is st w and Y is i
# X is t wi and Y is s
# X is  wis and Y is h
# X is wish and Y is e
# X is ishe and Y is s
# X is shes and Y is
# X is hes  and Y is t
# X is es t and Y is o
# X is s to and Y is
# X is  to  and Y is a
# X is to a and Y is l
# X is o al and Y is l
# X is  all and Y is
# X is all  and Y is t
# X is ll t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is m
# X is trym and Y is e
# X is ryme and Y is n
# X is ymen and Y is
# X is men  and Y is a
# X is en a and Y is n
# X is n an and Y is d
# X is  and and Y is
# X is and  and Y is a
# X is nd a and Y is l
# X is d al and Y is l
# X is  all and Y is
# X is all  and Y is t
# X is ll t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is b
# X is he b and Y is r
# X is e br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is s
# X is hers and Y is
# X is ers  and Y is a
# X is rs a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is s
# X is ters and Y is
# X is ers  and Y is o
# X is rs o and Y is n
# X is s on and Y is
# X is  on  and Y is t
# X is on t and Y is h
# X is n th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is a
# X is is a and Y is u
# X is s au and Y is s
# X is  aus and Y is p
# X is ausp and Y is i
# X is uspi and Y is c
# X is spic and Y is i
# X is pici and Y is o
# X is icio and Y is u
# X is ciou and Y is s
# X is ious and Y is
# X is ous  and Y is f
# X is us f and Y is e
# X is s fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is R
# X is of R and Y is a
# X is f Ra and Y is k
# X is  Rak and Y is s
# X is Raks and Y is h
# X is aksh and Y is a
# X is ksha and Y is
# X is sha  and Y is B
# X is ha B and Y is a
# X is a Ba and Y is n
# X is  Ban and Y is d
# X is Band and Y is h
# X is andh and Y is a
# X is ndha and Y is n
# X is dhan and Y is .
# X is han. and Y is
# X is an.  and Y is M
# X is n. M and Y is a
# X is . Ma and Y is y
# X is  May and Y is
# X is May  and Y is t
# X is ay t and Y is h
# X is y th and Y is i
# X is  thi and Y is s
# X is this and Y is
# X is his  and Y is f
# X is is f and Y is e
# X is s fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is f
# X is al f and Y is i
# X is l fi and Y is l
# X is  fil and Y is l
# X is fill and Y is e
# X is ille and Y is d
# X is lled and Y is
# X is led  and Y is w
# X is ed w and Y is i
# X is d wi and Y is t
# X is  wit and Y is h
# X is with and Y is
# X is ith  and Y is a
# X is th a and Y is f
# X is h af and Y is f
# X is  aff and Y is e
# X is affe and Y is c
# X is ffec and Y is t
# X is fect and Y is i
# X is ecti and Y is o
# X is ctio and Y is n
# X is tion and Y is
# X is ion  and Y is f
# X is on f and Y is u
# X is n fu and Y is l
# X is  ful and Y is f
# X is fulf and Y is i
# X is ulfi and Y is l
# X is lfil and Y is
# X is fil  and Y is t
# X is il t and Y is h
# X is l th and Y is e
# X is  the and Y is
# X is the  and Y is h
# X is he h and Y is o
# X is e ho and Y is p
# X is  hop and Y is e
# X is hope and Y is s
# X is opes and Y is ,
# X is pes, and Y is
# X is es,  and Y is a
# X is s, a and Y is s
# X is , as and Y is p
# X is  asp and Y is i
# X is aspi and Y is r
# X is spir and Y is a
# X is pira and Y is t
# X is irat and Y is i
# X is rati and Y is o
# X is atio and Y is n
# X is tion and Y is s
# X is ions and Y is
# X is ons  and Y is a
# X is ns a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is d
# X is nd d and Y is r
# X is d dr and Y is e
# X is  dre and Y is a
# X is drea and Y is m
# X is ream and Y is s
# X is eams and Y is
# X is ams  and Y is o
# X is ms o and Y is f
# X is s of and Y is
# X is  of  and Y is a
# X is of a and Y is l
# X is f al and Y is l
# X is  all and Y is
# X is all  and Y is o
# X is ll o and Y is u
# X is l ou and Y is r
# X is  our and Y is
# X is our  and Y is b
# X is ur b and Y is r
# X is r br and Y is o
# X is  bro and Y is t
# X is brot and Y is h
# X is roth and Y is e
# X is othe and Y is r
# X is ther and Y is s
# X is hers and Y is
# X is ers  and Y is a
# X is rs a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is s
# X is nd s and Y is i
# X is d si and Y is s
# X is  sis and Y is t
# X is sist and Y is e
# X is iste and Y is r
# X is ster and Y is s
# X is ters and Y is ,
# X is ers, and Y is
# X is rs,  and Y is a
# X is s, a and Y is n
# X is , an and Y is d
# X is  and and Y is
# X is and  and Y is b
# X is nd b and Y is r
# X is d br and Y is i
# X is  bri and Y is n
# X is brin and Y is g
# X is ring and Y is
# X is ing  and Y is a
# X is ng a and Y is f
# X is g af and Y is f
# X is  aff and Y is e
# X is affe and Y is c
# X is ffec and Y is t
# X is fect and Y is i
# X is ecti and Y is o
# X is ctio and Y is n
# X is tion and Y is
# X is ion  and Y is i
# X is on i and Y is n
# X is n in and Y is
# X is  in  and Y is t
# X is in t and Y is h
# X is n th and Y is e
# X is  the and Y is i
# X is thei and Y is r
# X is heir and Y is
# X is eir  and Y is l
# X is ir l and Y is i
# X is r li and Y is v
# X is  liv and Y is e
# X is live and Y is s
# X is ives and Y is .
# X is ves. and Y is T
# X is es.T and Y is o
# X is s.To and Y is d
# X is .Tod and Y is a
# X is Toda and Y is y
# X is oday and Y is ,
# X is day, and Y is
# X is ay,  and Y is w
# X is y, w and Y is h
# X is , wh and Y is i
# X is  whi and Y is l
# X is whil and Y is e
# X is hile and Y is
# X is ile  and Y is t
# X is le t and Y is h
# X is e th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is
# X is try  and Y is i
# X is ry i and Y is s
# X is y is and Y is
# X is  is  and Y is c
# X is is c and Y is e
# X is s ce and Y is l
# X is  cel and Y is e
# X is cele and Y is b
# X is eleb and Y is r
# X is lebr and Y is a
# X is ebra and Y is t
# X is brat and Y is i
# X is rati and Y is n
# X is atin and Y is g
# X is ting and Y is
# X is ing  and Y is t
# X is ng t and Y is h
# X is g th and Y is e
# X is  the and Y is
# X is the  and Y is f
# X is he f and Y is e
# X is e fe and Y is s
# X is  fes and Y is t
# X is fest and Y is i
# X is esti and Y is v
# X is stiv and Y is a
# X is tiva and Y is l
# X is ival and Y is
# X is val  and Y is o
# X is al o and Y is f
# X is l of and Y is
# X is  of  and Y is i
# X is of i and Y is n
# X is f in and Y is d
# X is  ind and Y is e
# X is inde and Y is p
# X is ndep and Y is e
# X is depe and Y is n
# X is epen and Y is d
# X is pend and Y is e
# X is ende and Y is n
# X is nden and Y is c
# X is denc and Y is e
# X is ence and Y is ,
# X is nce, and Y is
# X is ce,  and Y is p
# X is e, p and Y is e
# X is , pe and Y is o
# X is  peo and Y is p
# X is peop and Y is l
# X is eopl and Y is e
# X is ople and Y is
# X is ple  and Y is i
# X is le i and Y is n
# X is e in and Y is
# X is  in  and Y is s
# X is in s and Y is e
# X is n se and Y is v
# X is  sev and Y is e
# X is seve and Y is r
# X is ever and Y is a
# X is vera and Y is l
# X is eral and Y is
# X is ral  and Y is p
# X is al p and Y is a
# X is l pa and Y is r
# X is  par and Y is t
# X is part and Y is s
# X is arts and Y is
# X is rts  and Y is o
# X is ts o and Y is f
# X is s of and Y is
# X is  of  and Y is t
# X is of t and Y is h
# X is f th and Y is e
# X is  the and Y is
# X is the  and Y is c
# X is he c and Y is o
# X is e co and Y is u
# X is  cou and Y is n
# X is coun and Y is t
# X is ount and Y is r
# X is untr and Y is y
# X is ntry and Y is
# X is try  and Y is a
# X is ry a and Y is r
# X is y ar and Y is e
# X is  are and Y is
# X is are  and Y is f
# X is re f and Y is a
# X is e fa and Y is c
# X is  fac and Y is i
# X is faci and Y is n
# X is acin and Y is g
# X is cing and Y is
# X is ing  and Y is d
# X is ng d and Y is i
# X is g di and Y is f
# X is  dif and Y is f
# X is diff and Y is i
# X is iffi and Y is c
# X is ffic and Y is u
# X is ficu and Y is l
# X is icul and Y is t
# X is cult and Y is i
# X is ulti and Y is e
# X is ltie and Y is s
# X is ties and Y is
# X is ies  and Y is d
# X is es d and Y is u
# X is s du and Y is e
# X is  due and Y is
# X is due  and Y is t
# X is ue t and Y is o
# X is e to and Y is
# X is  to  and Y is f
# X is to f and Y is l
# X is o fl and Y is o
# X is  flo and Y is o
# X is floo and Y is d
# X is lood and Y is s
# X is oods and Y is
# X is ods  and Y is a
# X is ds a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is h
# X is nd h and Y is e
# X is d he and Y is a
# X is  hea and Y is v
# X is heav and Y is y
# X is eavy and Y is
# X is avy  and Y is r
# X is vy r and Y is a
# X is y ra and Y is i
# X is  rai and Y is n
# X is rain and Y is f
# X is ainf and Y is a
# X is infa and Y is l
# X is nfal and Y is l
# X is fall and Y is .
# X is all. and Y is
# X is ll.  and Y is M
# X is l. M and Y is a
# X is . Ma and Y is n
# X is  Man and Y is y
# X is Many and Y is
# X is any  and Y is h
# X is ny h and Y is a
# X is y ha and Y is v
# X is  hav and Y is e
# X is have and Y is
# X is ave  and Y is l
# X is ve l and Y is o
# X is e lo and Y is s
# X is  los and Y is t
# X is lost and Y is
# X is ost  and Y is t
# X is st t and Y is h
# X is t th and Y is e
# X is  the and Y is i
# X is thei and Y is r
# X is heir and Y is
# X is eir  and Y is d
# X is ir d and Y is e
# X is r de and Y is a
# X is  dea and Y is r
# X is dear and Y is
# X is ear  and Y is o
# X is ar o and Y is n
# X is r on and Y is e
# X is  one and Y is s
# X is ones and Y is .
# X is nes. and Y is
# X is es.  and Y is I
# X is s. I and Y is
# X is . I  and Y is e
# X is  I e and Y is x
# X is I ex and Y is p
# X is  exp and Y is r
# X is expr and Y is e
# X is xpre and Y is s
# X is pres and Y is s
# X is ress and Y is
# X is ess  and Y is m
# X is ss m and Y is y
# X is s my and Y is
# X is  my  and Y is c
# X is my c and Y is o
# X is y co and Y is n
# X is  con and Y is d
# X is cond and Y is o
# X is ondo and Y is l
# X is ndol and Y is e
# X is dole and Y is n
# X is olen and Y is c
# X is lenc and Y is e
# X is ence and Y is s
# X is nces and Y is
# X is ces  and Y is t
# X is es t and Y is o
# X is s to and Y is
# X is  to  and Y is t
# X is to t and Y is h
# X is o th and Y is e
# X is  the and Y is m
# X is them and Y is .
# X is hem. and Y is
# X is em.  and Y is T
# X is m. T and Y is h
# X is . Th and Y is e
# X is  The and Y is
# X is The  and Y is S
# X is he S and Y is t
# X is e St and Y is a
# X is  Sta and Y is t
# X is Stat and Y is e
# X is tate and Y is
# X is ate  and Y is G
# X is te G and Y is o
# X is e Go and Y is v
# X is  Gov and Y is e
# X is Gove and Y is r
# X is over and Y is n
# X is vern and Y is m
# X is ernm and Y is e
# X is rnme and Y is n
# X is nmen and Y is t
# X is ment and Y is s
# X is ents and Y is ,
# X is nts, and Y is
# X is ts,  and Y is t
# X is s, t and Y is h
# X is , th and Y is e
# X is  the and Y is
# X is the  and Y is C
# X is he C and Y is e
# X is e Ce and Y is n
# X is  Cen and Y is t
# X is Cent and Y is r
# X is entr and Y is a
# X is ntra and Y is l
# X is tral and Y is
# X is ral  and Y is G
# X is al G and Y is o
# X is l Go and Y is v
# X is  Gov and Y is e
# X is Gove and Y is r
# X is over and Y is n
# X is vern and Y is m
# X is ernm and Y is e
# X is rnme and Y is n
# X is nmen and Y is t
# X is ment and Y is
# X is ent  and Y is a
# X is nt a and Y is n
# X is t an and Y is d
# X is  and and Y is
# X is and  and Y is o
# X is nd o and Y is t
# X is d ot and Y is h
# X is  oth and Y is e
# X is othe and Y is r
# X is ther and Y is
# X is her  and Y is o
# X is er o and Y is r
# X is r or and Y is g
# X is  org and Y is a
# X is orga and Y is n
# X is rgan and Y is i
# X is gani and Y is z
# X is aniz and Y is a
# X is niza and Y is t
# X is izat and Y is i
# X is zati and Y is o
# X is atio and Y is n
# X is tion and Y is s
# X is ions and Y is
# X is ons  and Y is l
# X is ns l and Y is i
# X is s li and Y is k
# X is  lik and Y is e
# X is like and Y is
# X is ike  and Y is N
# X is ke N and Y is D
# X is e ND and Y is R
# X is  NDR and Y is F
# X is NDRF and Y is
# X is DRF  and Y is a
# X is RF a and Y is r
# X is F ar and Y is e
# X is  are and Y is
# X is are  and Y is s
# X is re s and Y is t
# X is e st and Y is r
# X is  str and Y is i
# X is stri and Y is v
# X is triv and Y is i
# X is rivi and Y is n
# X is ivin and Y is g
# X is ving and Y is
# X is ing  and Y is d
# X is ng d and Y is a
# X is g da and Y is y
# X is  day and Y is
# X is day  and Y is a
# X is ay a and Y is n
# X is y an and Y is d
# X is  and and Y is
# X is and  and Y is n
# X is nd n and Y is i
# X is d ni and Y is g
# X is  nig and Y is h
# X is nigh and Y is t
# X is ight and Y is
# X is ght  and Y is t
# X is ht t and Y is o
# X is t to and Y is
# X is  to  and Y is e
# X is to e and Y is a
# X is o ea and Y is s
# X is  eas and Y is e
# X is ease and Y is
# X is ase  and Y is t
# X is se t and Y is h
# X is e th and Y is e
# X is  the and Y is
# X is the  and Y is h
# X is he h and Y is a
# X is e ha and Y is r
# X is  har and Y is d
# X is hard and Y is s
# X is ards and Y is h
# X is rdsh and Y is i
# X is dshi and Y is p
# X is ship and Y is s
# X is hips and Y is
# X is ips  and Y is a
# X is ps a and Y is n
# X is s an and Y is d
# X is  and and Y is
# X is and  and Y is b
# X is nd b and Y is r
# X is d br and Y is i
# X is  bri and Y is n
# X is brin and Y is g
# X is ring and Y is
# X is ing  and Y is t
# X is ng t and Y is h
# X is g th and Y is e
# X is  the and Y is
# X is the  and Y is s
# X is he s and Y is i
# X is e si and Y is t
# X is  sit and Y is u
# X is situ and Y is a
# X is itua and Y is t
# X is tuat and Y is i
# X is uati and Y is o
# X is atio and Y is n
# X is tion and Y is
# X is ion  and Y is u
# X is on u and Y is n
# X is n un and Y is d
# X is  und and Y is e
# X is unde and Y is r
# X is nder and Y is
# X is der  and Y is c
# X is er c and Y is o
# X is r co and Y is n
# X is  con and Y is t
# X is cont and Y is r
# X is ontr and Y is o
# X is ntro and Y is l
# X is trol and Y is .
# {'My d': {'e': 1.0}, 'y de': {'a': 1.0}, ' dea': {'r': 1.0}, 'dear': {' ': 1.0}, 'ear ': {'c': 0.5, 'o': 0.5}, 'ar c': {'o': 1.0}, 'r co': {'u': 0.5, 'n': 0.5}, ' cou': {'n': 1.0}, 'coun': {'t': 1.0}, 'ount': {'r': 1.0}, 'untr': {'y': 1.0}, 'ntry': {'m': 0.6, ' ': 0.4}, 'trym': {'e': 1.0}, 'ryme': {'n': 1.0}, 'ymen': {',': 0.3333333333333333, '.': 0.3333333333333333, ' ': 0.3333333333333333}, 'men,': {'O': 1.0}, 'en,O': {'n': 1.0}, 'n,On': {' ': 1.0}, ',On ': {'t': 1.0}, 'On t': {'h': 1.0}, 'n th': {'i': 0.6666666666666666, 'e': 0.3333333333333333}, ' thi': {'s': 1.0}, 'this': {' ': 1.0}, 'his ': {'s': 0.25, 'c': 0.25, 'a': 0.25, 'f': 0.25}, 'is s': {'o': 1.0}, 's so': {'l': 1.0}, ' sol': {'e': 1.0}, 'sole': {'m': 1.0}, 'olem': {'n': 1.0}, 'lemn': {' ': 1.0}, 'emn ': {'d': 1.0}, 'mn d': {'a': 1.0}, 'n da': {'y': 1.0}, ' day': {' ': 1.0}, 'day ': {'o': 0.3333333333333333, 'i': 0.3333333333333333, 'a': 0.3333333333333333}, 'ay o': {'f': 1.0}, 'y of': {' ': 1.0}, ' of ': {'I': 0.14285714285714285, 'R': 0.2857142857142857, 'b': 0.14285714285714285, 'a': 0.14285714285714285, 'i': 0.14285714285714285, 't': 0.14285714285714285}, 'of I': {'n': 1.0}, 'f In': {'d': 1.0}, ' Ind': {'e': 1.0}, 'Inde': {'p': 1.0}, 'ndep': {'e': 1.0}, 'depe': {'n': 1.0}, 'epen': {'d': 1.0}, 'pend': {'e': 1.0}, 'ende': {'n': 1.0}, 'nden': {'c': 1.0}, 'denc': {'e': 1.0}, 'ence': {',': 0.6666666666666666, 's': 0.3333333333333333}, 'nce,': {' ': 1.0}, 'ce, ': {'m': 0.5, 'p': 0.5}, 'e, m': {'a': 1.0}, ', ma': {'n': 1.0}, ' man': {'y': 1.0}, 'many': {' ': 1.0}, 'any ': {'g': 0.5, 'h': 0.5}, 'ny g': {'r': 1.0}, 'y gr': {'e': 1.0}, ' gre': {'e': 1.0}, 'gree': {'t': 1.0}, 'reet': {'i': 1.0}, 'eeti': {'n': 1.0}, 'etin': {'g': 1.0}, 'ting': {'s': 0.5, ' ': 0.5}, 'ings': {' ': 1.0}, 'ngs ': {'t': 1.0}, 'gs t': {'o': 1.0}, 's to': {' ': 1.0}, ' to ': {'a': 0.4, 'f': 0.2, 't': 0.2, 'e': 0.2}, 'to a': {'l': 1.0}, 'o al': {'l': 1.0}, ' all': {' ': 1.0}, 'all ': {'c': 0.25, 't': 0.5, 'o': 0.25}, 'll c': {'o': 1.0}, 'l co': {'u': 1.0}, 'men.': {'T': 1.0}, 'en.T': {'o': 1.0}, 'n.To': {'d': 1.0}, '.Tod': {'a': 1.0}, 'Toda': {'y': 1.0}, 'oday': {' ': 0.5, ',': 0.5}, 'ay i': {'s': 1.0}, 'y is': {' ': 1.0}, ' is ': {'a': 0.5, 'c': 0.5}, 'is a': {'l': 0.5, 'u': 0.5}, 's al': {'s': 1.0}, ' als': {'o': 1.0}, 'also': {' ': 1.0}, 'lso ': {'t': 1.0}, 'so t': {'h': 1.0}, 'o th': {'e': 1.0}, ' the': {' ': 0.7857142857142857, 'i': 0.14285714285714285, 'm': 0.07142857142857142}, 'the ': {'f': 0.18181818181818182, 'l': 0.09090909090909091, 'c': 0.2727272727272727, 'b': 0.09090909090909091, 'h': 0.18181818181818182, 'C': 0.09090909090909091, 's': 0.09090909090909091}, 'he f': {'e': 1.0}, 'e fe': {'s': 1.0}, ' fes': {'t': 1.0}, 'fest': {'i': 1.0}, 'esti': {'v': 1.0}, 'stiv': {'a': 1.0}, 'tiva': {'l': 1.0}, 'ival': {' ': 1.0}, 'val ': {'o': 0.75, 'f': 0.25}, 'al o': {'f': 1.0}, 'l of': {' ': 1.0}, 'of R': {'a': 1.0}, 'f Ra': {'k': 1.0}, ' Rak': {'s': 1.0}, 'Raks': {'h': 1.0}, 'aksh': {'a': 1.0}, 'ksha': {' ': 1.0}, 'sha ': {'B': 1.0}, 'ha B': {'a': 1.0}, 'a Ba': {'n': 1.0}, ' Ban': {'d': 1.0}, 'Band': {'h': 1.0}, 'andh': {'a': 1.0}, 'ndha': {'n': 1.0}, 'dhan': {'.': 1.0}, 'han.': {' ': 1.0}, 'an. ': {'T': 0.5, 'M': 0.5}, 'n. T': {'h': 1.0}, '. Th': {'i': 0.5, 'e': 0.5}, ' Thi': {'s': 1.0}, 'This': {' ': 1.0}, 'is c': {'e': 1.0}, 's ce': {'n': 0.5, 'l': 0.5}, ' cen': {'t': 1.0}, 'cent': {'u': 1.0}, 'entu': {'r': 1.0}, 'ntur': {'i': 1.0}, 'turi': {'e': 1.0}, 'urie': {'s': 1.0}, 'ries': {'-': 1.0}, 'ies-': {'o': 1.0}, 'es-o': {'l': 1.0}, 's-ol': {'d': 1.0}, '-old': {' ': 1.0}, 'old ': {'t': 1.0}, 'ld t': {'r': 1.0}, 'd tr': {'a': 1.0}, ' tra': {'d': 1.0}, 'trad': {'i': 1.0}, 'radi': {'t': 1.0}, 'adit': {'i': 1.0}, 'diti': {'o': 1.0}, 'itio': {'n': 1.0}, 'tion': {' ': 0.6666666666666666, 's': 0.3333333333333333}, 'ion ': {'e': 0.25, 'f': 0.25, 'i': 0.25, 'u': 0.25}, 'on e': {'x': 1.0}, 'n ex': {'p': 1.0}, ' exp': {'r': 1.0}, 'expr': {'e': 1.0}, 'xpre': {'s': 1.0}, 'pres': {'s': 1.0}, 'ress': {'e':  ...

# %%
def sample_text(ctx,T,k):
    ctx=ctx[-k:]
    if T.get(ctx) is None:
        return " "
    possible_chars=list(T[ctx].keys())
    possible_values=list(T[ctx].values())
    
    return np.random.choice(possible_chars,p=possible_values)

# %%
sample_text("iste",model,4)
# Out:
# 'r'
